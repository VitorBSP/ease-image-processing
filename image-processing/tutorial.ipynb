# %%
from structure import combination, transformation
from utils import io, graphics

# %%
barca = io.read_image('../image/barcelona.png')
real = io.read_image('../image/real.png')
gremio = io.read_image('../image/gremio.jpeg')
inter = io.read_image('../image/inter.jpg')

# %%
# Checking number of channels
print(real.shape)
print(barca.shape)
print(gremio.shape)
print(inter.shape)
# Out:
# (265, 190, 4)
# (1024, 1010, 4)
# (473, 620, 3)
# (576, 580, 3)

# %%
real_barca = combination.transfer_histogram(real, barca)
gremio_inter = combination.transfer_histogram(gremio, inter)
# Out:
# e:\repos\image-processing\image-processing\structure\combination.py:33: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched_image = match_histograms(image1, image2, multichannel = True)

# %%
graphics.plot_image(real_barca)

# %%
graphics.plot_image(gremio_inter)

# %%
graphics.plot_result(real, barca, real_barca)

# %%
graphics.plot_result(gremio, inter, gremio_inter)

# %%
graphics.plot_histogram(barca)

# %%
draw_inter = transformation.image_to_draw(inter)
graphics.plot_image(draw_inter)
